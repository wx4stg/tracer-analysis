# %%
import xarray as xr

# %%
ds = xr.open_dataset('/Volumes/LtgSSD/tobac_saves/tobac_Save_20220917/seabreeze.zarr', engine='zarr', chunks='auto')

# %%
ds.feature_time_index
# Out:
# <xarray.DataArray 'feature_time_index' (feature: 16067)> Size: 129kB
# dask.array<open_dataset-feature_time_index, shape=(16067,), dtype=int64, chunksize=(16067,), chunktype=numpy.ndarray>
# Coordinates:
#   * feature  (feature) int64 129kB 1 2 3 4 5 6 ... 16063 16064 16065 16066 16067

# %%
ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                           (cell: 984, feature: 16067, x: 1001,
#                                        y: 1001, time: 293, track: 781)
# Coordinates:
#   * cell                              (cell) int64 8kB -1 5 9 ... 4728 4735 4740
#   * feature                           (feature) int64 129kB 1 2 ... 16066 16067
#   * time                              (time) datetime64[ns] 2kB 2022-09-17T00...
#   * track                             (track) float64 6kB 0.0 1.0 ... 780.0
#   * x                                 (x) float64 8kB -2.5e+05 ... 2.5e+05
#   * y                                 (y) float64 8kB -2.5e+05 ... 2.5e+05
# Data variables: (12/27)
#     cell_child_feature_count          (cell) float64 8kB dask.array<chunksize=(984,), meta=np.ndarray>
#     cell_parent_track_id              (cell) float64 8kB dask.array<chunksize=(984,), meta=np.ndarray>
# ...
